# %%
import pandas as pd

# %%
khis = pd.read_csv('C:\\Users\\Melvin M Shajan\\Desktop\\data_csv\\khis_kajiado_with_coords.csv')
khis.head(5)
# Out:
#          facility_name      orgUnit  orgUnit_level  \
# 0  amboseli dispensary  HzKPLEISiy4              5
# 1  amboseli dispensary  HzKPLEISiy4              5
# 2  amboseli dispensary  HzKPLEISiy4              5
# 3  amboseli dispensary  HzKPLEISiy4              5
# 4  amboseli dispensary  HzKPLEISiy4              5
#
#                             dataElement_name  dataElement_code  dataElement  \
# 0                                Brucellosis               NaN  nb9cfWgxYFc
# 1  MOH 711 MUAC 6 - 59 months Normal (Green)               NaN  BZbUjXynxfr
# 2                         MOH 711 Live birth               NaN  UqKC1DJnymn
# 3  MOH 711 MUAC 6 - 59 months Normal (Green)               NaN  BZbUjXynxfr
# 4    MOH 711 MUAC 6 - 59 months Severe (Red)               NaN  sTjfhcH5iXK
#
#        dx_type  period  value          County              Subcounty  \
# 0  dataElement  202202      1  kajiado county  loitokitok sub county
# ...

# %%
prompts = pd.read_csv('C:\\Users\\Melvin M Shajan\\Desktop\\data_csv\\prompts_no_duplicates (1).csv')
prompts.head(5)
# Out:
#          facility_name     Date/Time Opened              Intent  Intent_Count  \
# 0  amboseli dispensary  2022-07-13 09:28:00      pain_back_butt             1
# 1  amboseli dispensary  2022-07-13 09:29:00      pain_back_butt             1
# 2  amboseli dispensary  2022-07-13 11:30:00  medication_general             1
# 3  amboseli dispensary  2022-07-14 11:22:00         intercourse             1
# 4  amboseli dispensary  2022-07-15 09:56:00           heartburn             1
#
#            County              Subcounty  Latitude  Longitude  \
# 0  kajiado county  loitokitok sub county  -2.74492    37.3667
# 1  kajiado county  loitokitok sub county  -2.74492    37.3667
# 2  kajiado county  loitokitok sub county  -2.74492    37.3667
# 3  kajiado county  loitokitok sub county  -2.74492    37.3667
# 4  kajiado county  loitokitok sub county  -2.74492    37.3667
#
#                    Ward
# 0  Entonet/Lenkism Ward
# 1  Entonet/Lenkism Ward
# 2  Entonet/Lenkism Ward
# ...
